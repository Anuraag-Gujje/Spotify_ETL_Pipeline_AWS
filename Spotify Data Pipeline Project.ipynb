# %%
# !pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spotipy
#   Downloading spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages (from spotipy) (2.3.0)
# Collecting async-timeout>=4.0.3 (from redis>=3.5.3->spotipy)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (2025.1.31)
# Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-5.0.1 redis-5.2.1 spotipy-2.25.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
# Out:
# /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/0UTIJvLFGdZ1v7iAOWYXe6"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2021-08-18T10:11:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/18VcdfV5jJVjn10mh0vOYt',
#     'id': '18VcdfV5jJVjn10mh0vOYt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b76b065e0d971f747ccae967',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b76b065e0d971f747ccae967',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b76b065e0d971f747ccae967',
#       'width': 64}],
#     'name': 'Vibez',
#     'release_date': '2021-01-08',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:18VcdfV5jJVjn10mh0vOYt',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZsFI1h6hIdQRw2ti0hz81'},
#       'href': 'https://api.spotify.com/v1/artists/5ZsFI1h6hIdQRw2ti0hz81',
#       'id': '5ZsFI1h6hIdQRw2ti0hz81',
#       'name': 'ZAYN',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZsFI1h6hIdQRw2ti0hz81'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/18VcdfV5jJVjn10mh0vOYt'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZsFI1h6hIdQRw2ti0hz81'},
#      'href': 'https://api.spotify.com/v1/artists/5ZsFI1h6hIdQRw2ti0hz81',
#      'id': '5ZsFI1h6hIdQRw2ti0hz81',
#      'name': 'ZAYN',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ZsFI1h6hIdQRw2ti0hz81'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 163127,
#    'external_ids': {'isrc': 'USRC12003149'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/709F3MwiVvLD0LQXeKs5Cz'},
#    'href': 'https://api.spotify.com/v1/tracks/709F3MwiVvLD0LQXeKs5Cz',
#    'id': '709F3MwiVvLD0LQXeKs5Cz',
#    'name': 'Vibez',
#    'popularity': 46,
#    'uri': 'spotify:track:709F3MwiVvLD0LQXeKs5Cz',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-11-26T17:30:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'HT',
#     'JM',
#     'LS',
#     'LR',
#     'MW',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'PR',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'LC',
#     'VC',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'PR',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6rIbiUMmZJfqJRnXhVxFvg',
#     'id': '6rIbiUMmZJfqJRnXhVxFvg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d3ce97395ff522b0d70c1094',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d3ce97395ff522b0d70c1094',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d3ce97395ff522b0d70c1094',
#       'width': 64}],
#     'name': 'Dream Your Life Away',
#     'release_date': '2014-09-08',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6rIbiUMmZJfqJRnXhVxFvg',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10exVja0key0uqUkk6LJRT'},
#       'href': 'https://api.spotify.com/v1/artists/10exVja0key0uqUkk6LJRT',
#       'id': '10exVja0key0uqUkk6LJRT',
#       'name': 'Vance Joy',
#       'type': 'artist',
#       'uri': 'spotify:artist:10exVja0key0uqUkk6LJRT'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6rIbiUMmZJfqJRnXhVxFvg'},
#     'total_tracks': 13},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10exVja0key0uqUkk6LJRT'},
#      'href': 'https://api.spotify.com/v1/artists/10exVja0key0uqUkk6LJRT',
#      'id': '10exVja0key0uqUkk6LJRT',
#      'name': 'Vance Joy',
#      'type': 'artist',
#      'uri': 'spotify:artist:10exVja0key0uqUkk6LJRT'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 204280,
#    'external_ids': {'isrc': 'AULI01385760'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7yq4Qj7cqayVTp3FF9CWbm'},
#    'href': 'https://api.spotify.com/v1/tracks/7yq4Qj7cqayVTp3FF9CWbm',
#    'id': '7yq4Qj7cqayVTp3FF9CWbm',
#    'name': 'Riptide',
#    'popularity': 76,
#    'uri': 'spotify:track:7yq4Qj7cqayVTp3FF9CWbm',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-12-06T19:01:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0KTj6k94XZh0c6IEMfxeWV',
#     'id': '0KTj6k94XZh0c6IEMfxeWV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739e495fb707973f3390850eea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029e495fb707973f3390850eea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519e495fb707973f3390850eea',
#       'width': 64}],
#     'name': 'Dreamland (+ Bonus Levels)',
#     'release_date': '2020-08-06',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0KTj6k94XZh0c6IEMfxeWV',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#       'href': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#       'id': '4yvcSjfu4PC0CYQyLy4wSq',
#       'name': 'Glass Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0KTj6k94XZh0c6IEMfxeWV'},
#     'total_tracks': 18},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#      'href': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#      'id': '4yvcSjfu4PC0CYQyLy4wSq',
#      'name': 'Glass Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#    'disc_number': 1,
#    'track_number': 14,
#    'duration_ms': 238805,
#    'external_ids': {'isrc': 'GBUM72000433'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/02MWAaffLxlfxAUY7c5dvx'},
#    'href': 'https://api.spotify.com/v1/tracks/02MWAaffLxlfxAUY7c5dvx',
#    'id': '02MWAaffLxlfxAUY7c5dvx',
#    'name': 'Heat Waves',
#    'popularity': 29,
#    'uri': 'spotify:track:02MWAaffLxlfxAUY7c5dvx',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-08-18T10:09:24Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0VKcOEVdDLf95KdHfBw9AR',
#     'id': '0VKcOEVdDLf95KdHfBw9AR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730c232fde2858d83554d58841',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020c232fde2858d83554d58841',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510c232fde2858d83554d58841',
#       'width': 64}],
#     'name': 'Night & Day (Day Edition)',
#     'release_date': '2018-07-13',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0VKcOEVdDLf95KdHfBw9AR',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#       'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#       'id': '7gAppWoH7pcYmphCVTXkzs',
#       'name': 'The Vamps',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0VKcOEVdDLf95KdHfBw9AR'},
#     'total_tracks': 18},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#      'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#      'id': '7gAppWoH7pcYmphCVTXkzs',
#      'name': 'The Vamps',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 206053,
#    'external_ids': {'isrc': 'GBUM71800361'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/68q0rYDrGaUcaAMT2dn4Mc'},
#    'href': 'https://api.spotify.com/v1/tracks/68q0rYDrGaUcaAMT2dn4Mc',
#    'id': '68q0rYDrGaUcaAMT2dn4Mc',
#    'name': 'Hair Too Long',
#    'popularity': 34,
#    'uri': 'spotify:track:68q0rYDrGaUcaAMT2dn4Mc',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-08-18T10:07:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['KR'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['KR'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6CQwJn7tvfUKi4U85zuEu8',
#     'id': '6CQwJn7tvfUKi4U85zuEu8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c915bb90940c2e76e678f167',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c915bb90940c2e76e678f167',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c915bb90940c2e76e678f167',
#       'width': 64}],
#     'name': 'Like 1999',
#     'release_date': '2021-02-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6CQwJn7tvfUKi4U85zuEu8',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#       'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#       'id': '7blXVKBSxdFZsIqlhdViKc',
#       'name': 'Valley',
#       'type': 'artist',
#       'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CQwJn7tvfUKi4U85zuEu8'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7blXVKBSxdFZsIqlhdViKc'},
#      'href': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc',
#      'id': '7blXVKBSxdFZsIqlhdViKc',
#      'name': 'Valley',
#      'type': 'artist',
#      'uri': 'spotify:artist:7blXVKBSxdFZsIqlhdViKc'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 144742,
#    'external_ids': {'isrc': 'CAUM72100015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3aHYf6AXlWujDG9CzzT95i'},
#    'href': 'https://api.spotify.com/v1/tracks/3aHYf6AXlWujDG9CzzT95i',
#    'id': '3aHYf6AXlWujDG9CzzT95i',
#    'name': 'Like 1999',
#    'popularity': 18,
#    'uri': 'spotify:track:3aHYf6AXlWujDG9CzzT95i',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-11-25T19:21:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4Cq0dfyCX1msQ6ZRbdT4YG',
#     'id': '4Cq0dfyCX1msQ6ZRbdT4YG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273107d930ebe7cba0ff31c605c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02107d930ebe7cba0ff31c605c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851107d930ebe7cba0ff31c605c',
#       'width': 64}],
#     'name': 'Midnight (feat. Liam Payne)',
#     'release_date': '2020-04-08',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4Cq0dfyCX1msQ6ZRbdT4YG',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#       'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#       'id': '4AVFqumd2ogHFlRbKIjp1t',
#       'name': 'Alesso',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pUo3fmmHT8bhCyHE52hA6'},
#       'href': 'https://api.spotify.com/v1/artists/5pUo3fmmHT8bhCyHE52hA6',
#       'id': '5pUo3fmmHT8bhCyHE52hA6',
#       'name': 'Liam Payne',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pUo3fmmHT8bhCyHE52hA6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Cq0dfyCX1msQ6ZRbdT4YG'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AVFqumd2ogHFlRbKIjp1t'},
#      'href': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t',
#      'id': '4AVFqumd2ogHFlRbKIjp1t',
#      'name': 'Alesso',
#      'type': 'artist',
#      'uri': 'spotify:artist:4AVFqumd2ogHFlRbKIjp1t'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pUo3fmmHT8bhCyHE52hA6'},
#      'href': 'https://api.spotify.com/v1/artists/5pUo3fmmHT8bhCyHE52hA6',
#      'id': '5pUo3fmmHT8bhCyHE52hA6',
#      'name': 'Liam Payne',
#      'type': 'artist',
#      'uri': 'spotify:artist:5pUo3fmmHT8bhCyHE52hA6'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 220140,
#    'external_ids': {'isrc': 'USUG12000913'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ZTTUAjJCd4NMZmIU7RB4c'},
#    'href': 'https://api.spotify.com/v1/tracks/4ZTTUAjJCd4NMZmIU7RB4c',
#    'id': '4ZTTUAjJCd4NMZmIU7RB4c',
#    'name': 'Midnight (feat. Liam Payne)',
#    'popularity': 56,
#    'uri': 'spotify:track:4ZTTUAjJCd4NMZmIU7RB4c',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-08-18T10:12:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/7FUNRteYv2Flt9Lr8JHFIR',
#     'id': '7FUNRteYv2Flt9Lr8JHFIR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273017b009cfe0fd69ba09d3e24',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02017b009cfe0fd69ba09d3e24',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851017b009cfe0fd69ba09d3e24',
#       'width': 64}],
#     'name': 'Easy (with Kacey Musgraves feat. Mark Ronson)',
#     'release_date': '2020-12-10',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7FUNRteYv2Flt9Lr8JHFIR',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WGpXCj9YhhfX11TToZcXP'},
#       'href': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP',
#       'id': '3WGpXCj9YhhfX11TToZcXP',
#       'name': 'Troye Sivan',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WGpXCj9YhhfX11TToZcXP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/70kkdajctXSbqSMJbQO424'},
#       'href': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424',
#       'id': '70kkdajctXSbqSMJbQO424',
#       'name': 'Kacey Musgraves',
#       'type': 'artist',
#       'uri': 'spotify:artist:70kkdajctXSbqSMJbQO424'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hv9jJF3adDNsBSIQDqcjp'},
#       'href': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp',
#       'id': '3hv9jJF3adDNsBSIQDqcjp',
#       'name': 'Mark Ronson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hv9jJF3adDNsBSIQDqcjp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7FUNRteYv2Flt9Lr8JHFIR'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WGpXCj9YhhfX11TToZcXP'},
#      'href': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP',
#      'id': '3WGpXCj9YhhfX11TToZcXP',
#      'name': 'Troye Sivan',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WGpXCj9YhhfX11TToZcXP'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/70kkdajctXSbqSMJbQO424'},
#      'href': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424',
#      'id': '70kkdajctXSbqSMJbQO424',
#      'name': 'Kacey Musgraves',
#      'type': 'artist',
#      'uri': 'spotify:artist:70kkdajctXSbqSMJbQO424'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hv9jJF3adDNsBSIQDqcjp'},
#      'href': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp',
#      'id': '3hv9jJF3adDNsBSIQDqcjp',
#      'name': 'Mark Ronson',
#      'type': 'artist',
#      'uri': 'spotify:artist:3hv9jJF3adDNsBSIQDqcjp'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 213571,
#    'external_ids': {'isrc': 'AUUM72000950'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4XWaUb7mKRcJR5RPp4IIDr'},
#    'href': 'https://api.spotify.com/v1/tracks/4XWaUb7mKRcJR5RPp4IIDr',
#    'id': '4XWaUb7mKRcJR5RPp4IIDr',
#    'name': 'Easy (with Kacey Musgraves feat. Mark Ronson)',
#    'popularity': 52,
#    'uri': 'spotify:track:4XWaUb7mKRcJR5RPp4IIDr',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-11-25T19:22:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/44qy89HXAh4e0ab35rlY2J',
#     'id': '44qy89HXAh4e0ab35rlY2J',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735262ec58d9c180434ff7ec14',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025262ec58d9c180434ff7ec14',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515262ec58d9c180434ff7ec14',
#       'width': 64}],
#     'name': 'Wake Up (Deluxe)',
#     'release_date': '2015-10-13',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:44qy89HXAh4e0ab35rlY2J',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#       'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#       'id': '7gAppWoH7pcYmphCVTXkzs',
#       'name': 'The Vamps',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44qy89HXAh4e0ab35rlY2J'},
#     'total_tracks': 18},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#      'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#      'id': '7gAppWoH7pcYmphCVTXkzs',
#      'name': 'The Vamps',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#    'disc_number': 1,
#    'track_number': 7,
#    'duration_ms': 179440,
#    'external_ids': {'isrc': 'GBUM71505937'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7I8EGPtqTwlC0UlCAkpYtP'},
#    'href': 'https://api.spotify.com/v1/tracks/7I8EGPtqTwlC0UlCAkpYtP',
#    'id': '7I8EGPtqTwlC0UlCAkpYtP',
#    'name': 'I Found A Girl',
#    'popularity': 48,
#    'uri': 'spotify:track:7I8EGPtqTwlC0UlCAkpYtP',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-08-18T10:16:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
# ...
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dTDSDu2MBMhgGniZBpPhQ'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75ois9nn8xMuOgVk2oCN1C'},
#      'href': 'https://api.spotify.com/v1/artists/75ois9nn8xMuOgVk2oCN1C',
#      'id': '75ois9nn8xMuOgVk2oCN1C',
#      'name': 'New Rules',
#      'type': 'artist',
#      'uri': 'spotify:artist:75ois9nn8xMuOgVk2oCN1C'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 177561,
#    'external_ids': {'isrc': 'UKLNX2000059'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/76SiX7ZyXoL8CwBvVdhC24'},
#    'href': 'https://api.spotify.com/v1/tracks/76SiX7ZyXoL8CwBvVdhC24',
#    'id': '76SiX7ZyXoL8CwBvVdhC24',
#    'name': 'Pasta',
#    'popularity': 0,
#    'uri': 'spotify:track:76SiX7ZyXoL8CwBvVdhC24',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-12-30T09:06:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4DOC4Vu1nbDlVetELknFhP',
#     'id': '4DOC4Vu1nbDlVetELknFhP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273478621f2e8eae44631ce0813',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02478621f2e8eae44631ce0813',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851478621f2e8eae44631ce0813',
#       'width': 64}],
#     'name': 'Missing You - EP',
#     'release_date': '2019-04-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4DOC4Vu1nbDlVetELknFhP',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#       'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#       'id': '7gAppWoH7pcYmphCVTXkzs',
#       'name': 'The Vamps',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4DOC4Vu1nbDlVetELknFhP'},
#     'total_tracks': 4},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gAppWoH7pcYmphCVTXkzs'},
#      'href': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs',
#      'id': '7gAppWoH7pcYmphCVTXkzs',
#      'name': 'The Vamps',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gAppWoH7pcYmphCVTXkzs'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 214986,
#    'external_ids': {'isrc': 'GBUM71900664'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0LcNMuOiULmxJK3bdHTfDF'},
#    'href': 'https://api.spotify.com/v1/tracks/0LcNMuOiULmxJK3bdHTfDF',
#    'id': '0LcNMuOiULmxJK3bdHTfDF',
#    'name': 'Missing You',
#    'popularity': 42,
#    'uri': 'spotify:track:0LcNMuOiULmxJK3bdHTfDF',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-12-30T09:31:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4q1mJMIhtUJJCKtTnMBD1q',
#     'id': '4q1mJMIhtUJJCKtTnMBD1q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273275d2c68881f78d764f7745a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02275d2c68881f78d764f7745a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851275d2c68881f78d764f7745a',
#       'width': 64}],
#     'name': 'OT',
#     'release_date': '2017-09-06',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4q1mJMIhtUJJCKtTnMBD1q',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#       'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#       'id': '73eAAfRkS2Vi4hx68oTJJE',
#       'name': 'John K',
#       'type': 'artist',
#       'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4q1mJMIhtUJJCKtTnMBD1q'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#      'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#      'id': '73eAAfRkS2Vi4hx68oTJJE',
#      'name': 'John K',
#      'type': 'artist',
#      'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 191885,
#    'external_ids': {'isrc': 'GBKPL1786897'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1YuIEfhp8umr6QSal4FTK4'},
#    'href': 'https://api.spotify.com/v1/tracks/1YuIEfhp8umr6QSal4FTK4',
#    'id': '1YuIEfhp8umr6QSal4FTK4',
#    'name': 'OT',
#    'popularity': 0,
#    'uri': 'spotify:track:1YuIEfhp8umr6QSal4FTK4',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-12-30T09:32:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#    'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#    'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#    'type': 'user',
#    'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/1LA3eirJ1NylPXjS1gbiD5',
#     'id': '1LA3eirJ1NylPXjS1gbiD5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27332db4a1bfc362abd17ab1c18',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0232db4a1bfc362abd17ab1c18',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485132db4a1bfc362abd17ab1c18',
#       'width': 64}],
#     'name': 'love + everything else',
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1LA3eirJ1NylPXjS1gbiD5',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#       'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#       'id': '73eAAfRkS2Vi4hx68oTJJE',
#       'name': 'John K',
#       'type': 'artist',
#       'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1LA3eirJ1NylPXjS1gbiD5'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73eAAfRkS2Vi4hx68oTJJE'},
#      'href': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE',
#      'id': '73eAAfRkS2Vi4hx68oTJJE',
#      'name': 'John K',
#      'type': 'artist',
#      'uri': 'spotify:artist:73eAAfRkS2Vi4hx68oTJJE'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 145315,
#    'external_ids': {'isrc': 'USSM11902691'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3D2H0RZzOXziswr9UHbpyb'},
#    'href': 'https://api.spotify.com/v1/tracks/3D2H0RZzOXziswr9UHbpyb',
#    'id': '3D2H0RZzOXziswr9UHbpyb',
#    'name': 'if we never met',
#    'popularity': 50,
#    'uri': 'spotify:track:3D2H0RZzOXziswr9UHbpyb',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '18VcdfV5jJVjn10mh0vOYt'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Vibez'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2021-01-08'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/18VcdfV5jJVjn10mh0vOYt'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '18VcdfV5jJVjn10mh0vOYt',
#   'name': 'Vibez',
#   'release_date': '2021-01-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/18VcdfV5jJVjn10mh0vOYt'},
#  {'album_id': '6rIbiUMmZJfqJRnXhVxFvg',
#   'name': 'Dream Your Life Away',
#   'release_date': '2014-09-08',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/6rIbiUMmZJfqJRnXhVxFvg'},
#  {'album_id': '0KTj6k94XZh0c6IEMfxeWV',
#   'name': 'Dreamland (+ Bonus Levels)',
#   'release_date': '2020-08-06',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0KTj6k94XZh0c6IEMfxeWV'},
#  {'album_id': '0VKcOEVdDLf95KdHfBw9AR',
#   'name': 'Night & Day (Day Edition)',
#   'release_date': '2018-07-13',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0VKcOEVdDLf95KdHfBw9AR'},
#  {'album_id': '6CQwJn7tvfUKi4U85zuEu8',
#   'name': 'Like 1999',
#   'release_date': '2021-02-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6CQwJn7tvfUKi4U85zuEu8'},
#  {'album_id': '4Cq0dfyCX1msQ6ZRbdT4YG',
#   'name': 'Midnight (feat. Liam Payne)',
#   'release_date': '2020-04-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4Cq0dfyCX1msQ6ZRbdT4YG'},
#  {'album_id': '7FUNRteYv2Flt9Lr8JHFIR',
#   'name': 'Easy (with Kacey Musgraves feat. Mark Ronson)',
#   'release_date': '2020-12-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7FUNRteYv2Flt9Lr8JHFIR'},
#  {'album_id': '44qy89HXAh4e0ab35rlY2J',
#   'name': 'Wake Up (Deluxe)',
#   'release_date': '2015-10-13',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/44qy89HXAh4e0ab35rlY2J'},
#  {'album_id': '79jCjSW0TiYcTKhJLeQ9Hk',
#   'name': 'Flames (feat. Ruel) [Lastlings Remix]',
#   'release_date': '2019-08-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/79jCjSW0TiYcTKhJLeQ9Hk'},
#  {'album_id': '2D0Hi3Jj6RFnpWDcSa0Otu',
#   'name': 'Youngblood (Deluxe)',
#   'release_date': '2018-06-15',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2D0Hi3Jj6RFnpWDcSa0Otu'},
#  {'album_id': '6GKIr03B2yvdP0TkWiGJVV',
#   'name': '5 Seconds Of Summer',
#   'release_date': '2014-06-27',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/6GKIr03B2yvdP0TkWiGJVV'},
#  {'album_id': '1zbH0DnpYxaoqTojXNLQb6',
#   'name': '13 Reasons Why (Season 3)',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1zbH0DnpYxaoqTojXNLQb6'},
#  {'album_id': '46K4raQPIGem3N031upNj9',
#   'name': 'CALM',
#   'release_date': '2020-03-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/46K4raQPIGem3N031upNj9'},
#  {'album_id': '46K4raQPIGem3N031upNj9',
#   'name': 'CALM',
#   'release_date': '2020-03-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/46K4raQPIGem3N031upNj9'},
#  {'album_id': '4f4IpP7HEwJX7TGb8y9Yjk',
#   'name': 'Hard to Breathe',
#   'release_date': '2018-04-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4f4IpP7HEwJX7TGb8y9Yjk'},
#  {'album_id': '12gXA8pXYzj9bycyyKSGAa',
#   'name': 'Meet The Vamps',
#   'release_date': '2014-01-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/12gXA8pXYzj9bycyyKSGAa'},
#  {'album_id': '1fP5UnRB0WNWNHSZRHsRCR',
#   'name': 'Feel Good (with Daya)',
#   'release_date': '2017-03-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1fP5UnRB0WNWNHSZRHsRCR'},
#  {'album_id': '4jKdXIJckKh7la6xHuKwRT',
#   'name': 'True Colors',
#   'release_date': '2015-05-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4jKdXIJckKh7la6xHuKwRT'},
#  {'album_id': '4jKdXIJckKh7la6xHuKwRT',
#   'name': 'True Colors',
#   'release_date': '2015-05-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4jKdXIJckKh7la6xHuKwRT'},
#  {'album_id': '773GsAWk3z8mGgMDeR7n1A',
#   'name': 'The World From The Side Of The Moon (Deluxe)',
#   'release_date': '2013-01-01',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/773GsAWk3z8mGgMDeR7n1A'},
#  {'album_id': '4tYt0x29RobSYgYzvgXdTC',
#   'name': 'Girls In Purgatory',
#   'release_date': '2021-10-07',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/4tYt0x29RobSYgYzvgXdTC'},
#  {'album_id': '4nProAxFavzKkbaRQ2Otyk',
#   'name': 'Summer Of Love',
#   'release_date': '2021-08-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4nProAxFavzKkbaRQ2Otyk'},
#  {'album_id': '34ETNTT7uLskCDqx2qGFCN',
#   'name': 'Those Nights (Nickay Remix)',
#   'release_date': '2020-12-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/34ETNTT7uLskCDqx2qGFCN'},
#  {'album_id': '6ErxPYc0KcJgLzQnpMGsth',
#   'name': 'Empires On Fire',
#   'release_date': '2017-11-03',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6ErxPYc0KcJgLzQnpMGsth'},
#  {'album_id': '707Yo7tTEf4TYZVIVde1uM',
#   'name': "Don't Play",
#   'release_date': '2021-01-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/707Yo7tTEf4TYZVIVde1uM'},
#  {'album_id': '2K3EExCTnagUD59napCSVD',
#   'name': 'Same Dark Places',
#   'release_date': '2017-03-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2K3EExCTnagUD59napCSVD'},
#  {'album_id': '3WrufJir7I61NkvkDwxero',
#   'name': 'In A Tidal Wave Of Mystery (Deluxe Edition)',
#   'release_date': '2013',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3WrufJir7I61NkvkDwxero'},
#  {'album_id': '5zseibu9WEsPaZmkJUMkz1',
#   'name': 'California 37',
#   'release_date': '2012-04-17',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5zseibu9WEsPaZmkJUMkz1'},
#  {'album_id': '6zXb9FQMzawvY2Au8Kxky3',
#   'name': 'Black Star Elephant',
#   'release_date': '2014',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6zXb9FQMzawvY2Au8Kxky3'},
#  {'album_id': '5zseibu9WEsPaZmkJUMkz1',
#   'name': 'California 37',
#   'release_date': '2012-04-17',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5zseibu9WEsPaZmkJUMkz1'},
#  {'album_id': '7m7F7SQ3BXvIpvOgjW51Gp',
#   'name': 'Some Nights',
#   'release_date': '2012-02-14',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/7m7F7SQ3BXvIpvOgjW51Gp'},
#  {'album_id': '1CwXS6MAz8Wo7K4TzW9iuR',
#   'name': 'Save Me, San Francisco (Golden Gate Edition)',
#   'release_date': '2010-12-01',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/1CwXS6MAz8Wo7K4TzW9iuR'},
#  {'album_id': '1oHY6eQmEG8skElDvFgKz2',
#   'name': 'Talking Dreams (Deluxe Edition)',
#   'release_date': '2013-10-04',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1oHY6eQmEG8skElDvFgKz2'},
#  {'album_id': '2hnaJ8ktG2FSP1EthsCo6N',
#   'name': 'Battleground (Deluxe Edition)',
#   'release_date': '2011-01-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2hnaJ8ktG2FSP1EthsCo6N'},
#  {'album_id': '6SQWwNCTTPmS1DaXQNRDOy',
#   'name': 'When the Morning Comes',
#   'release_date': '2015-11-13',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6SQWwNCTTPmS1DaXQNRDOy'},
#  {'album_id': '7j7cqgeWmYH9PbKe3S5oJj',
#   'name': 'The Story of Us',
#   'release_date': '2017-09-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/7j7cqgeWmYH9PbKe3S5oJj'},
#  {'album_id': '2GjVC7rlXXFFtiVJdsnCvX',
#   'name': 'Sunshine State of Mind',
#   'release_date': '2011-07-12',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2GjVC7rlXXFFtiVJdsnCvX'},
#  {'album_id': '1DNx0H5ZX1ax3yyRwtgT4S',
#   'name': "Don't Forget About Me, Demos",
#   'release_date': '2018-10-16',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/1DNx0H5ZX1ax3yyRwtgT4S'},
#  {'album_id': '15sy3XQFShOFiDpKoxByyA',
#   'name': 'Paradise',
#   'release_date': '2020-10-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/15sy3XQFShOFiDpKoxByyA'},
#  {'album_id': '4VyUvPueWuM8Jnkk62gcos',
#   'name': 'Without Fear',
#   'release_date': '2019-10-04',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4VyUvPueWuM8Jnkk62gcos'},
#  {'album_id': '7jGNAMzrW5HMXdxl9XyBMG',
#   'name': 'Without Fear',
#   'release_date': '2019-10-04',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/7jGNAMzrW5HMXdxl9XyBMG'},
#  {'album_id': '7jGNAMzrW5HMXdxl9XyBMG',
#   'name': 'Without Fear',
#   'release_date': '2019-10-04',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/7jGNAMzrW5HMXdxl9XyBMG'},
#  {'album_id': '1tQY26OJ6PNFZoBP9I9nXu',
#   'name': 'Bad Blood',
#   'release_date': '2021-08-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1tQY26OJ6PNFZoBP9I9nXu'},
#  {'album_id': '0zocAVUSizQ74Cn8nCsN3a',
#   'name': 'Our Song',
#   'release_date': '2021-05-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0zocAVUSizQ74Cn8nCsN3a'},
#  {'album_id': '69Pj3ce9XFZUi3XuQylLKf',
#   'name': 'Night & Day (Night Edition)',
#   'release_date': '2017-07-14',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/69Pj3ce9XFZUi3XuQylLKf'},
#  {'album_id': '12gXA8pXYzj9bycyyKSGAa',
#   'name': 'Meet The Vamps',
#   'release_date': '2014-01-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/12gXA8pXYzj9bycyyKSGAa'},
#  {'album_id': '4JFyas1xaX9NnAvRP9DhKF',
#   'name': 'All The Lies',
#   'release_date': '2019-03-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4JFyas1xaX9NnAvRP9DhKF'},
#  {'album_id': '0VKcOEVdDLf95KdHfBw9AR',
#   'name': 'Night & Day (Day Edition)',
#   'release_date': '2018-07-13',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0VKcOEVdDLf95KdHfBw9AR'},
#  {'album_id': '69Pj3ce9XFZUi3XuQylLKf',
#   'name': 'Night & Day (Night Edition)',
#   'release_date': '2017-07-14',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/69Pj3ce9XFZUi3XuQylLKf'},
#  {'album_id': '06mXfvDsRZNfnsGZvX2zpb',
#   'name': 'Music Of The Spheres',
#   'release_date': '2021-10-15',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/06mXfvDsRZNfnsGZvX2zpb'},
#  {'album_id': '029WUoBjWc7Js1QiPH3mw0',
#   'name': 'James Arthur (Deluxe)',
#   'release_date': '2013-11-04',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/029WUoBjWc7Js1QiPH3mw0'},
#  {'album_id': '7oiJYvEJHsmYtrgviAVIBD',
#   'name': 'Back from the Edge',
#   'release_date': '2016-10-28',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/7oiJYvEJHsmYtrgviAVIBD'},
#  {'album_id': '7oiJYvEJHsmYtrgviAVIBD',
#   'name': 'Back from the Edge',
#   'release_date': '2016-10-28',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/7oiJYvEJHsmYtrgviAVIBD'},
#  {'album_id': '0P4xzdUBgd8cMncwM7okcd',
#   'name': "It'll All Make Sense In The End",
#   'release_date': '2021-11-05',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0P4xzdUBgd8cMncwM7okcd'},
#  {'album_id': '0cm9LOQUBK3JUgyoRj238z',
#   'name': 'YOU',
#   'release_date': '2019-10-18',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/0cm9LOQUBK3JUgyoRj238z'},
#  {'album_id': '1oqnHxrKI3Gq8MKgAGDtMr',
#   'name': 'The Greatest Showman: Reimagined (Deluxe)',
#   'release_date': '2017-12-08',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/1oqnHxrKI3Gq8MKgAGDtMr'},
#  {'album_id': '0EW257HwkJ1CblYgM9GIAY',
#   'name': 'You (feat. Travis Barker)',
#   'release_date': '2019-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0EW257HwkJ1CblYgM9GIAY'},
#  {'album_id': '262JcveAzA4ngibAS3Ocm8',
#   'name': 'Lasting Lover',
#   'release_date': '2020-09-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/262JcveAzA4ngibAS3Ocm8'},
#  {'album_id': '6fQ1xPtYMzoBiqvSO2LcpT',
#   'name': 'Naked',
#   'release_date': '2017-11-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6fQ1xPtYMzoBiqvSO2LcpT'},
#  {'album_id': '20lOt6G8MHv8ZO7ViOmiP7',
#   'name': 'Native',
#   'release_date': '2013-01-01',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/20lOt6G8MHv8ZO7ViOmiP7'},
#  {'album_id': '3cfAM8b8KqJRoIzt3zLKqw',
#   'name': 'A Head Full of Dreams',
#   'release_date': '2015-12-04',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/3cfAM8b8KqJRoIzt3zLKqw'},
#  {'album_id': '2udv3G6saR7mLvp20Sfvcw',
#   'name': 'Start A Riot',
#   'release_date': '2015-12-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2udv3G6saR7mLvp20Sfvcw'},
#  {'album_id': '1ITjhViDumL9llxAJYdKiC',
#   'name': 'Politics of Living',
#   'release_date': '2018-09-28',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1ITjhViDumL9llxAJYdKiC'},
#  {'album_id': '1ITjhViDumL9llxAJYdKiC',
#   'name': 'Politics of Living',
#   'release_date': '2018-09-28',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1ITjhViDumL9llxAJYdKiC'},
#  {'album_id': '1ttGpGzOEi6JDDOHO4qD1y',
#   'name': 'In A Perfect World (Expanded Edition)',
#   'release_date': '2013-06-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1ttGpGzOEi6JDDOHO4qD1y'},
#  {'album_id': '5FOy59kuACS78PonjSQflD',
#   'name': 'One Day at a Time (Deluxe)',
#   'release_date': '2020-11-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5FOy59kuACS78PonjSQflD'},
#  {'album_id': '5FOy59kuACS78PonjSQflD',
#   'name': 'One Day at a Time (Deluxe)',
#   'release_date': '2020-11-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5FOy59kuACS78PonjSQflD'},
#  {'album_id': '4QT1dg8zQoHuXF2HZbWWEB',
#   'name': 'Skiing Workout Mix',
#   'release_date': '2018-02-02',
#   'total_tracks': 28,
#   'url': 'https://open.spotify.com/album/4QT1dg8zQoHuXF2HZbWWEB'},
#  {'album_id': '1pCA38N6MkLlthXtAOvZTU',
#   'name': 'JORDI (Deluxe)',
#   'release_date': '2021-06-11',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1pCA38N6MkLlthXtAOvZTU'},
#  {'album_id': '6LtzdMGhOCh9s6sssWrpuD',
#   'name': 'V (Asia Tour Edition)',
#   'release_date': '2015-05-18',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/6LtzdMGhOCh9s6sssWrpuD'},
#  {'album_id': '0kNjRXrrBrXGUFkGhf2HVI',
#   'name': 'Break My Heart',
#   'release_date': '2021-01-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0kNjRXrrBrXGUFkGhf2HVI'},
#  {'album_id': '2W8nO4x2KlHc3z3xxe23PW',
#   'name': 'sucks to see you doing better (extended)',
#   'release_date': '2020-12-11',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2W8nO4x2KlHc3z3xxe23PW'},
#  {'album_id': '2W8nO4x2KlHc3z3xxe23PW',
#   'name': 'sucks to see you doing better (extended)',
#   'release_date': '2020-12-11',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2W8nO4x2KlHc3z3xxe23PW'},
#  {'album_id': '2XJb3KWRBjAarZvPf6Rqwu',
#   'name': 'too many feelings',
#   'release_date': '2021-02-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2XJb3KWRBjAarZvPf6Rqwu'},
#  {'album_id': '6WlRyrfOBZGYA5u5TmloKY',
#   'name': 'times',
#   'release_date': '2021-02-19',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6WlRyrfOBZGYA5u5TmloKY'},
#  {'album_id': '2qIbHfs93z6eDwGoAdCkXA',
#   'name': '8 Letters',
#   'release_date': '2018-08-31',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/2qIbHfs93z6eDwGoAdCkXA'},
#  {'album_id': '085TF4mnNbXQT0m2X05cb0',
#   'name': 'Big Plans',
#   'release_date': '2019-01-17',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/085TF4mnNbXQT0m2X05cb0'},
#  {'album_id': '0cVSrL39wn0PkBm9PFf6G2',
#   'name': 'The Good Times and The Bad Ones',
#   'release_date': '2021-01-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0cVSrL39wn0PkBm9PFf6G2'},
#  {'album_id': '2CxrZinzjDXZidyx5EP214',
#   'name': 'Make You Mine',
#   'release_date': '2019-08-09',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/2CxrZinzjDXZidyx5EP214'},
#  {'album_id': '62JmTTk0wLV4Y5XB5yFIt0',
#   'name': 'Crisis / Secret / Set Me Free',
#   'release_date': '2021-12-03',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/62JmTTk0wLV4Y5XB5yFIt0'},
#  {'album_id': '1wQJ3BLua9Lmy7lcFLHFjh',
#   'name': 'Watching The Sky',
#   'release_date': '2018-06-08',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1wQJ3BLua9Lmy7lcFLHFjh'},
#  {'album_id': '5LSdG0zNzytvmF6CRPVvKq',
#   'name': 'Say Yes',
#   'release_date': '2020-06-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5LSdG0zNzytvmF6CRPVvKq'},
#  {'album_id': '73EOzYiyGuila7KonedyLZ',
#   'name': 'Armor',
#   'release_date': '2014-04-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/73EOzYiyGuila7KonedyLZ'},
#  {'album_id': '2W5GS6nrw3I7VZxUtVX8Bf',
#   'name': 'Stuck In My Head (feat. AJ Mitchell)',
#   'release_date': '2020-11-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2W5GS6nrw3I7VZxUtVX8Bf'},
#  {'album_id': '72gGqv8n64gwUBY10SPI3N',
#   'name': 'CHICKEN TENDIES',
#   'release_date': '2021-02-19',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/72gGqv8n64gwUBY10SPI3N'},
#  {'album_id': '7rU4vsRIhRRfMt3qy6ADND',
#   'name': 'Drown (feat. Clinton Kane)',
#   'release_date': '2020-02-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7rU4vsRIhRRfMt3qy6ADND'},
#  {'album_id': '13j0Kg7NR6uwvE1TEXlNQi',
#   'name': 'TWENTYTWENTY',
#   'release_date': '2020-11-20',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/13j0Kg7NR6uwvE1TEXlNQi'},
#  {'album_id': '0kCeC3O3QGbCYDJGCGUIce',
#   'name': 'Dive',
#   'release_date': '2019-12-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0kCeC3O3QGbCYDJGCGUIce'},
#  {'album_id': '6FgtuX3PtiB5civjHYhc52',
#   'name': 'Safe Haven',
#   'release_date': '2017-05-05',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6FgtuX3PtiB5civjHYhc52'},
#  {'album_id': '2hZK1aGxPqE8XMyUK8bV79',
#   'name': 'Somebody That You Loved',
#   'release_date': '2019-08-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2hZK1aGxPqE8XMyUK8bV79'},
#  {'album_id': '6imRhQCpFOLRWvBf9R0ncF',
#   'name': 'Year of the Sunflower',
#   'release_date': '2019-12-06',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/6imRhQCpFOLRWvBf9R0ncF'},
#  {'album_id': '16ilcI6xOgSh3Jd3bxF6MI',
#   'name': 'Reminds Me Of You',
#   'release_date': '2020-12-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/16ilcI6xOgSh3Jd3bxF6MI'},
#  {'album_id': '1fxAZZDF1whhrPcNmEPHlt',
#   'name': 'Cross My Mind: The Mixtape',
#   'release_date': '2017-08-18',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1fxAZZDF1whhrPcNmEPHlt'},
#  {'album_id': '1QRP5lutJodPixU2EWfnD7',
#   'name': 'Dangerous Woman',
#   'release_date': '2016-04-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1QRP5lutJodPixU2EWfnD7'},
#  {'album_id': '04iJhZyPeR71awYvirkeCt',
#   'name': 'The Long Way',
#   'release_date': '2021-09-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/04iJhZyPeR71awYvirkeCt'},
#  {'album_id': '6VjNaalNwGON6ymlTEWNn8',
#   'name': 'Sun Goes Down',
#   'release_date': '2017-06-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6VjNaalNwGON6ymlTEWNn8'},
#  {'album_id': '5dTDSDu2MBMhgGniZBpPhQ',
#   'name': 'Pasta',
#   'release_date': '2020-03-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5dTDSDu2MBMhgGniZBpPhQ'},
#  {'album_id': '4DOC4Vu1nbDlVetELknFhP',
#   'name': 'Missing You - EP',
#   'release_date': '2019-04-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4DOC4Vu1nbDlVetELknFhP'},
#  {'album_id': '4q1mJMIhtUJJCKtTnMBD1q',
#   'name': 'OT',
#   'release_date': '2017-09-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4q1mJMIhtUJJCKtTnMBD1q'},
#  {'album_id': '1LA3eirJ1NylPXjS1gbiD5',
#   'name': 'love + everything else',
#   'release_date': '2020-11-12',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1LA3eirJ1NylPXjS1gbiD5'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2021-08-18T10:11:38Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/m3ppce6sj5mx5ataow0k2bdh9'},
#   'href': 'https://api.spotify.com/v1/users/m3ppce6sj5mx5ataow0k2bdh9',
#   'id': 'm3ppce6sj5mx5ataow0k2bdh9',
#   'type': 'user',
#   'uri': 'spotify:user:m3ppce6sj5mx5ataow0k2bdh9'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/18VcdfV5jJVjn10mh0vOYt',
#    'id': '18VcdfV5jJVjn10mh0vOYt',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b76b065e0d971f747ccae967',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b76b065e0d971f747ccae967',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b76b065e0d971f747ccae967',
#      'width': 64}],
#    'name': 'Vibez',
#    'release_date': '2021-01-08',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:18VcdfV5jJVjn10mh0vOYt',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZsFI1h6hIdQRw2ti0hz81'},
#      'href': 'https://api.spotify.com/v1/artists/5ZsFI1h6hIdQRw2ti0hz81',
#      'id': '5ZsFI1h6hIdQRw2ti0hz81',
#      'name': 'ZAYN',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ZsFI1h6hIdQRw2ti0hz81'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/18VcdfV5jJVjn10mh0vOYt'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZsFI1h6hIdQRw2ti0hz81'},
#     'href': 'https://api.spotify.com/v1/artists/5ZsFI1h6hIdQRw2ti0hz81',
#     'id': '5ZsFI1h6hIdQRw2ti0hz81',
#     'name': 'ZAYN',
#     'type': 'artist',
#     'uri': 'spotify:artist:5ZsFI1h6hIdQRw2ti0hz81'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 163127,
#   'external_ids': {'isrc': 'USRC12003149'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/709F3MwiVvLD0LQXeKs5Cz'},
#   'href': 'https://api.spotify.com/v1/tracks/709F3MwiVvLD0LQXeKs5Cz',
#   'id': '709F3MwiVvLD0LQXeKs5Cz',
#   'name': 'Vibez',
#   'popularity': 46,
#   'uri': 'spotify:track:709F3MwiVvLD0LQXeKs5Cz',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5ZsFI1h6hIdQRw2ti0hz81',
#   'artist_name': 'ZAYN',
#   'external_url': 'https://api.spotify.com/v1/artists/5ZsFI1h6hIdQRw2ti0hz81'},
#  {'artist_id': '10exVja0key0uqUkk6LJRT',
#   'artist_name': 'Vance Joy',
#   'external_url': 'https://api.spotify.com/v1/artists/10exVja0key0uqUkk6LJRT'},
#  {'artist_id': '4yvcSjfu4PC0CYQyLy4wSq',
#   'artist_name': 'Glass Animals',
#   'external_url': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '7blXVKBSxdFZsIqlhdViKc',
#   'artist_name': 'Valley',
#   'external_url': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc'},
#  {'artist_id': '4AVFqumd2ogHFlRbKIjp1t',
#   'artist_name': 'Alesso',
#   'external_url': 'https://api.spotify.com/v1/artists/4AVFqumd2ogHFlRbKIjp1t'},
#  {'artist_id': '5pUo3fmmHT8bhCyHE52hA6',
#   'artist_name': 'Liam Payne',
#   'external_url': 'https://api.spotify.com/v1/artists/5pUo3fmmHT8bhCyHE52hA6'},
#  {'artist_id': '3WGpXCj9YhhfX11TToZcXP',
#   'artist_name': 'Troye Sivan',
#   'external_url': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP'},
#  {'artist_id': '70kkdajctXSbqSMJbQO424',
#   'artist_name': 'Kacey Musgraves',
#   'external_url': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424'},
#  {'artist_id': '3hv9jJF3adDNsBSIQDqcjp',
#   'artist_name': 'Mark Ronson',
#   'external_url': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '0GG2cWaonE4JPrjcCCQ1EG',
#   'artist_name': 'SG Lewis',
#   'external_url': 'https://api.spotify.com/v1/artists/0GG2cWaonE4JPrjcCCQ1EG'},
#  {'artist_id': '5xkAtLTf309LAGZTbvULBn',
#   'artist_name': 'Ruel',
#   'external_url': 'https://api.spotify.com/v1/artists/5xkAtLTf309LAGZTbvULBn'},
#  {'artist_id': '5Rl15oVamLq7FbSb0NNBNy',
#   'artist_name': '5 Seconds of Summer',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy'},
#  {'artist_id': '5Rl15oVamLq7FbSb0NNBNy',
#   'artist_name': '5 Seconds of Summer',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy'},
#  {'artist_id': '5Rl15oVamLq7FbSb0NNBNy',
#   'artist_name': '5 Seconds of Summer',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy'},
#  {'artist_id': '5Rl15oVamLq7FbSb0NNBNy',
#   'artist_name': '5 Seconds of Summer',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy'},
#  {'artist_id': '5Rl15oVamLq7FbSb0NNBNy',
#   'artist_name': '5 Seconds of Summer',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy'},
#  {'artist_id': '3gTsbSe32ITI2q210AqNjH',
#   'artist_name': 'Mountenz',
#   'external_url': 'https://api.spotify.com/v1/artists/3gTsbSe32ITI2q210AqNjH'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '2ZRQcIgzPCVaT9XKhXZIzh',
#   'artist_name': 'Gryffin',
#   'external_url': 'https://api.spotify.com/v1/artists/2ZRQcIgzPCVaT9XKhXZIzh'},
#  {'artist_id': '45eNHdiiabvmbp4erw26rg',
#   'artist_name': 'ILLENIUM',
#   'external_url': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg'},
#  {'artist_id': '6Dd3NScHWwnW6obMFbl1BH',
#   'artist_name': 'Daya',
#   'external_url': 'https://api.spotify.com/v1/artists/6Dd3NScHWwnW6obMFbl1BH'},
#  {'artist_id': '2qxJFvFYMEDqd7ui6kSAcq',
#   'artist_name': 'Zedd',
#   'external_url': 'https://api.spotify.com/v1/artists/2qxJFvFYMEDqd7ui6kSAcq'},
#  {'artist_id': '0C8ZW7ezQVs4URX5aX7Kqx',
#   'artist_name': 'Selena Gomez',
#   'external_url': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx'},
#  {'artist_id': '2qxJFvFYMEDqd7ui6kSAcq',
#   'artist_name': 'Zedd',
#   'external_url': 'https://api.spotify.com/v1/artists/2qxJFvFYMEDqd7ui6kSAcq'},
#  {'artist_id': '50JJSqHUf2RQ9xsHs0KMHg',
#   'artist_name': 'Jon Bellion',
#   'external_url': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg'},
#  {'artist_id': '6p5JxpTc7USNnBnLzctyd4',
#   'artist_name': 'Phillip Phillips',
#   'external_url': 'https://api.spotify.com/v1/artists/6p5JxpTc7USNnBnLzctyd4'},
#  {'artist_id': '5yvGiZLSWJTPBlZpVbPnEZ',
#   'artist_name': 'Julia Wolf',
#   'external_url': 'https://api.spotify.com/v1/artists/5yvGiZLSWJTPBlZpVbPnEZ'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '0GM7qgcRCORpGnfcN2tCiB',
#   'artist_name': 'Tainy',
#   'external_url': 'https://api.spotify.com/v1/artists/0GM7qgcRCORpGnfcN2tCiB'},
#  {'artist_id': '0p3tzEAt0XWrBqbrwBoN1I',
#   'artist_name': 'Kyle Hume',
#   'external_url': 'https://api.spotify.com/v1/artists/0p3tzEAt0XWrBqbrwBoN1I'},
#  {'artist_id': '5URQ2rB5uHsUvy2CAW1vYp',
#   'artist_name': 'Nickay',
#   'external_url': 'https://api.spotify.com/v1/artists/5URQ2rB5uHsUvy2CAW1vYp'},
#  {'artist_id': '4qWnlmXWuGv2TtuxtIWlJX',
#   'artist_name': 'BANNERS',
#   'external_url': 'https://api.spotify.com/v1/artists/4qWnlmXWuGv2TtuxtIWlJX'},
#  {'artist_id': '1zNqDE7qDGCsyzJwohVaoX',
#   'artist_name': 'Anne-Marie',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqDE7qDGCsyzJwohVaoX'},
#  {'artist_id': '1nzgtKYFckznkcVMR3Gg4z',
#   'artist_name': 'KSI',
#   'external_url': 'https://api.spotify.com/v1/artists/1nzgtKYFckznkcVMR3Gg4z'},
#  {'artist_id': '5fyDppLDl1juIu1BcUT5zh',
#   'artist_name': 'Digital Farm Animals',
#   'external_url': 'https://api.spotify.com/v1/artists/5fyDppLDl1juIu1BcUT5zh'},
#  {'artist_id': '3VAxb3UskTNiHAKh4UeOEv',
#   'artist_name': 'JR JR',
#   'external_url': 'https://api.spotify.com/v1/artists/3VAxb3UskTNiHAKh4UeOEv'},
#  {'artist_id': '4gwpcMTbLWtBUlOijbVpuu',
#   'artist_name': 'Capital Cities',
#   'external_url': 'https://api.spotify.com/v1/artists/4gwpcMTbLWtBUlOijbVpuu'},
#  {'artist_id': '3FUY2gzHeIiaesXtOAdB7A',
#   'artist_name': 'Train',
#   'external_url': 'https://api.spotify.com/v1/artists/3FUY2gzHeIiaesXtOAdB7A'},
#  {'artist_id': '0awl5piYwO0CDTHEkCjUhn',
#   'artist_name': 'Nico & Vinz',
#   'external_url': 'https://api.spotify.com/v1/artists/0awl5piYwO0CDTHEkCjUhn'},
#  {'artist_id': '3FUY2gzHeIiaesXtOAdB7A',
#   'artist_name': 'Train',
#   'external_url': 'https://api.spotify.com/v1/artists/3FUY2gzHeIiaesXtOAdB7A'},
#  {'artist_id': '5nCi3BB41mBaMH9gfr6Su0',
#   'artist_name': 'fun.',
#   'external_url': 'https://api.spotify.com/v1/artists/5nCi3BB41mBaMH9gfr6Su0'},
#  {'artist_id': '3FUY2gzHeIiaesXtOAdB7A',
#   'artist_name': 'Train',
#   'external_url': 'https://api.spotify.com/v1/artists/3FUY2gzHeIiaesXtOAdB7A'},
#  {'artist_id': '1PbBg2aYjWLKRk84zJK15x',
#   'artist_name': 'Echosmith',
#   'external_url': 'https://api.spotify.com/v1/artists/1PbBg2aYjWLKRk84zJK15x'},
#  {'artist_id': '2NhdGz9EDv2FeUw6udu2g1',
#   'artist_name': 'The Wanted',
#   'external_url': 'https://api.spotify.com/v1/artists/2NhdGz9EDv2FeUw6udu2g1'},
#  {'artist_id': '5xKp3UyavIBUsGy3DQdXeF',
#   'artist_name': 'A Great Big World',
#   'external_url': 'https://api.spotify.com/v1/artists/5xKp3UyavIBUsGy3DQdXeF'},
#  {'artist_id': '3ApUX1o6oSz321MMECyIYd',
#   'artist_name': 'Quinn XCII',
#   'external_url': 'https://api.spotify.com/v1/artists/3ApUX1o6oSz321MMECyIYd'},
#  {'artist_id': '5JMLG56F1X5mFmWNmS0iAp',
#   'artist_name': 'Chelsea Cutler',
#   'external_url': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp'},
#  {'artist_id': '3ao3jf5d70Tf4fPh2bnXVl',
#   'artist_name': 'We The Kings',
#   'external_url': 'https://api.spotify.com/v1/artists/3ao3jf5d70Tf4fPh2bnXVl'},
#  {'artist_id': '6USv9qhCn6zfxlBQIYJ9qs',
#   'artist_name': 'Dominic Fike',
#   'external_url': 'https://api.spotify.com/v1/artists/6USv9qhCn6zfxlBQIYJ9qs'},
#  {'artist_id': '0xRXCcSX89eobfrshSVdyu',
#   'artist_name': 'MEDUZA',
#   'external_url': 'https://api.spotify.com/v1/artists/0xRXCcSX89eobfrshSVdyu'},
#  {'artist_id': '5KNNVgR6LBIABRIomyCwKJ',
#   'artist_name': 'Dermot Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/5KNNVgR6LBIABRIomyCwKJ'},
#  {'artist_id': '5KNNVgR6LBIABRIomyCwKJ',
#   'artist_name': 'Dermot Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/5KNNVgR6LBIABRIomyCwKJ'},
#  {'artist_id': '5KNNVgR6LBIABRIomyCwKJ',
#   'artist_name': 'Dermot Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/5KNNVgR6LBIABRIomyCwKJ'},
#  {'artist_id': '5KNNVgR6LBIABRIomyCwKJ',
#   'artist_name': 'Dermot Kennedy',
#   'external_url': 'https://api.spotify.com/v1/artists/5KNNVgR6LBIABRIomyCwKJ'},
#  {'artist_id': '5yqxqwMiLwc8876vZQe8qX',
#   'artist_name': 'Porsche Love',
#   'external_url': 'https://api.spotify.com/v1/artists/5yqxqwMiLwc8876vZQe8qX'},
#  {'artist_id': '1zNqDE7qDGCsyzJwohVaoX',
#   'artist_name': 'Anne-Marie',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqDE7qDGCsyzJwohVaoX'},
#  {'artist_id': '1Hsdzj7Dlq2I7tHP7501T4',
#   'artist_name': 'Niall Horan',
#   'external_url': 'https://api.spotify.com/v1/artists/1Hsdzj7Dlq2I7tHP7501T4'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '4YXycRbyyAE0wozTk7QMEq',
#   'artist_name': 'Matoma',
#   'external_url': 'https://api.spotify.com/v1/artists/4YXycRbyyAE0wozTk7QMEq'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '0NGAZxHanS9e0iNHpR8f2W',
#   'artist_name': 'Alok',
#   'external_url': 'https://api.spotify.com/v1/artists/0NGAZxHanS9e0iNHpR8f2W'},
#  {'artist_id': '4bL2B6hmLlMWnUEZnorEtG',
#   'artist_name': 'Felix Jaehn',
#   'external_url': 'https://api.spotify.com/v1/artists/4bL2B6hmLlMWnUEZnorEtG'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '4ehtJnVumNf6xzSCDk8aLB',
#   'artist_name': 'Martin Jensen',
#   'external_url': 'https://api.spotify.com/v1/artists/4ehtJnVumNf6xzSCDk8aLB'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '1zNqDE7qDGCsyzJwohVaoX',
#   'artist_name': 'Anne-Marie',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqDE7qDGCsyzJwohVaoX'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4exLIFE8sISLr28sqG1qNX',
#   'artist_name': 'Travis Barker',
#   'external_url': 'https://api.spotify.com/v1/artists/4exLIFE8sISLr28sqG1qNX'},
#  {'artist_id': '1IueXOQyABrMOprrzwQJWN',
#   'artist_name': 'Sigala',
#   'external_url': 'https://api.spotify.com/v1/artists/1IueXOQyABrMOprrzwQJWN'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '4IWBUUAFIplrNtaOHcJPRM',
#   'artist_name': 'James Arthur',
#   'external_url': 'https://api.spotify.com/v1/artists/4IWBUUAFIplrNtaOHcJPRM'},
#  {'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'artist_name': 'OneRepublic',
#   'external_url': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '4qWnlmXWuGv2TtuxtIWlJX',
#   'artist_name': 'BANNERS',
#   'external_url': 'https://api.spotify.com/v1/artists/4qWnlmXWuGv2TtuxtIWlJX'},
#  {'artist_id': '4BxCuXFJrSWGi1KHcVqaU4',
#   'artist_name': 'Kodaline',
#   'external_url': 'https://api.spotify.com/v1/artists/4BxCuXFJrSWGi1KHcVqaU4'},
#  {'artist_id': '4BxCuXFJrSWGi1KHcVqaU4',
#   'artist_name': 'Kodaline',
#   'external_url': 'https://api.spotify.com/v1/artists/4BxCuXFJrSWGi1KHcVqaU4'},
#  {'artist_id': '4BxCuXFJrSWGi1KHcVqaU4',
#   'artist_name': 'Kodaline',
#   'external_url': 'https://api.spotify.com/v1/artists/4BxCuXFJrSWGi1KHcVqaU4'},
#  {'artist_id': '4BxCuXFJrSWGi1KHcVqaU4',
#   'artist_name': 'Kodaline',
#   'external_url': 'https://api.spotify.com/v1/artists/4BxCuXFJrSWGi1KHcVqaU4'},
#  {'artist_id': '4BxCuXFJrSWGi1KHcVqaU4',
#   'artist_name': 'Kodaline',
#   'external_url': 'https://api.spotify.com/v1/artists/4BxCuXFJrSWGi1KHcVqaU4'},
#  {'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'external_url': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP'},
#  {'artist_id': '1l7ZsJRRS8wlW3WfJfPfNS',
#   'artist_name': 'Christina Aguilera',
#   'external_url': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS'},
#  {'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'external_url': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP'},
#  {'artist_id': '181bsRPaVXVlUKXrxwZfHK',
#   'artist_name': 'Megan Thee Stallion',
#   'external_url': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK'},
#  {'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'external_url': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP'},
#  {'artist_id': '2TAqN8fwfaKauvviN4pOsv',
#   'artist_name': 'JC Stewart',
#   'external_url': 'https://api.spotify.com/v1/artists/2TAqN8fwfaKauvviN4pOsv'},
#  {'artist_id': '7blXVKBSxdFZsIqlhdViKc',
#   'artist_name': 'Valley',
#   'external_url': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc'},
#  {'artist_id': '7blXVKBSxdFZsIqlhdViKc',
#   'artist_name': 'Valley',
#   'external_url': 'https://api.spotify.com/v1/artists/7blXVKBSxdFZsIqlhdViKc'},
#  {'artist_id': '5xkAtLTf309LAGZTbvULBn',
#   'artist_name': 'Ruel',
#   'external_url': 'https://api.spotify.com/v1/artists/5xkAtLTf309LAGZTbvULBn'},
#  {'artist_id': '0GG2cWaonE4JPrjcCCQ1EG',
#   'artist_name': 'SG Lewis',
#   'external_url': 'https://api.spotify.com/v1/artists/0GG2cWaonE4JPrjcCCQ1EG'},
#  {'artist_id': '2jnIB6XdLvnJUeNTy5A0J2',
#   'artist_name': "Why Don't We",
#   'external_url': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2'},
#  {'artist_id': '2jnIB6XdLvnJUeNTy5A0J2',
#   'artist_name': "Why Don't We",
#   'external_url': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2'},
#  {'artist_id': '2jnIB6XdLvnJUeNTy5A0J2',
#   'artist_name': "Why Don't We",
#   'external_url': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2'},
#  {'artist_id': '4vxaQs6vK54nK89J1VtLex',
#   'artist_name': 'PUBLIC',
#   'external_url': 'https://api.spotify.com/v1/artists/4vxaQs6vK54nK89J1VtLex'},
#  {'artist_id': '4VdV2qRAYBLINR6uU72V1J',
#   'artist_name': 'Joshua Bassett',
#   'external_url': 'https://api.spotify.com/v1/artists/4VdV2qRAYBLINR6uU72V1J'},
#  {'artist_id': '6VxCmtR7S3yz4vnzsJqhSV',
#   'artist_name': 'Sheppard',
#   'external_url': 'https://api.spotify.com/v1/artists/6VxCmtR7S3yz4vnzsJqhSV'},
#  {'artist_id': '3JQMhGLU0F6IeOzlDZiUNW',
#   'artist_name': 'KiD RAiN',
#   'external_url': 'https://api.spotify.com/v1/artists/3JQMhGLU0F6IeOzlDZiUNW'},
#  {'artist_id': '2WROyFfIOmKtRopsTrIL52',
#   'artist_name': 'Landon Austin',
#   'external_url': 'https://api.spotify.com/v1/artists/2WROyFfIOmKtRopsTrIL52'},
#  {'artist_id': '0rlKkLkpsCnJbZethGBfAk',
#   'artist_name': 'Captain Cuts',
#   'external_url': 'https://api.spotify.com/v1/artists/0rlKkLkpsCnJbZethGBfAk'},
#  {'artist_id': '6dn6x1XOng3LOAnfTjUn77',
#   'artist_name': 'AJ Mitchell',
#   'external_url': 'https://api.spotify.com/v1/artists/6dn6x1XOng3LOAnfTjUn77'},
#  {'artist_id': '7okSU80WTrn4LXlyXYbX3P',
#   'artist_name': 'Clinton Kane',
#   'external_url': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P'},
#  {'artist_id': '60d24wfXkVzDSfLS6hyCjZ',
#   'artist_name': 'Martin Garrix',
#   'external_url': 'https://api.spotify.com/v1/artists/60d24wfXkVzDSfLS6hyCjZ'},
#  {'artist_id': '7okSU80WTrn4LXlyXYbX3P',
#   'artist_name': 'Clinton Kane',
#   'external_url': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P'},
#  {'artist_id': '0DxPHf2flBAcV2SnZPg3SV',
#   'artist_name': 'Jake Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0DxPHf2flBAcV2SnZPg3SV'},
#  {'artist_id': '2KgFtUjEtayfuximKppSAq',
#   'artist_name': 'Josie Dunne',
#   'external_url': 'https://api.spotify.com/v1/artists/2KgFtUjEtayfuximKppSAq'},
#  {'artist_id': '3GtCKJA4SkOxN65MWjm82R',
#   'artist_name': 'Hot Shade',
#   'external_url': 'https://api.spotify.com/v1/artists/3GtCKJA4SkOxN65MWjm82R'},
#  {'artist_id': '6lB8vOoI4DRrrVxXwuV19c',
#   'artist_name': 'Mike Perry',
#   'external_url': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c'},
#  {'artist_id': '1PU4kQGbRVMSyvawEYEjFp',
#   'artist_name': 'Chris James',
#   'external_url': 'https://api.spotify.com/v1/artists/1PU4kQGbRVMSyvawEYEjFp'},
#  {'artist_id': '2WzaAvm2bBCf4pEhyuDgCY',
#   'artist_name': 'Ruth B.',
#   'external_url': 'https://api.spotify.com/v1/artists/2WzaAvm2bBCf4pEhyuDgCY'},
#  {'artist_id': '5veVxxPm1vzgi6pO2iVA8L',
#   'artist_name': 'Bruno Martini',
#   'external_url': 'https://api.spotify.com/v1/artists/5veVxxPm1vzgi6pO2iVA8L'},
#  {'artist_id': '2WuKU0SYZOQyY3MmE4vtez',
#   'artist_name': 'New Hope Club',
#   'external_url': 'https://api.spotify.com/v1/artists/2WuKU0SYZOQyY3MmE4vtez'},
#  {'artist_id': '0DxPHf2flBAcV2SnZPg3SV',
#   'artist_name': 'Jake Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0DxPHf2flBAcV2SnZPg3SV'},
#  {'artist_id': '4MCBfE4596Uoi2O4DtmEMz',
#   'artist_name': 'Juice WRLD',
#   'external_url': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz'},
#  {'artist_id': '2tIP7SsRs7vjIcLrU85W8J',
#   'artist_name': 'The Kid LAROI',
#   'external_url': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J'},
#  {'artist_id': '7hOGhpa8RMSuDOWntGIAJt',
#   'artist_name': 'A R I Z O N A',
#   'external_url': 'https://api.spotify.com/v1/artists/7hOGhpa8RMSuDOWntGIAJt'},
#  {'artist_id': '4u5smJBskI6Adzv08PuiUP',
#   'artist_name': 'Kiiara',
#   'external_url': 'https://api.spotify.com/v1/artists/4u5smJBskI6Adzv08PuiUP'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '11p2E654TTU8e0nZWBR4AL',
#   'artist_name': 'Mark Ambor',
#   'external_url': 'https://api.spotify.com/v1/artists/11p2E654TTU8e0nZWBR4AL'},
#  {'artist_id': '5veVxxPm1vzgi6pO2iVA8L',
#   'artist_name': 'Bruno Martini',
#   'external_url': 'https://api.spotify.com/v1/artists/5veVxxPm1vzgi6pO2iVA8L'},
#  {'artist_id': '0Ymiodu1YzvWwqq528sWiW',
#   'artist_name': 'ADORA',
#   'external_url': 'https://api.spotify.com/v1/artists/0Ymiodu1YzvWwqq528sWiW'},
#  {'artist_id': '75ois9nn8xMuOgVk2oCN1C',
#   'artist_name': 'New Rules',
#   'external_url': 'https://api.spotify.com/v1/artists/75ois9nn8xMuOgVk2oCN1C'},
#  {'artist_id': '7gAppWoH7pcYmphCVTXkzs',
#   'artist_name': 'The Vamps',
#   'external_url': 'https://api.spotify.com/v1/artists/7gAppWoH7pcYmphCVTXkzs'},
#  {'artist_id': '73eAAfRkS2Vi4hx68oTJJE',
#   'artist_name': 'John K',
#   'external_url': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE'},
#  {'artist_id': '73eAAfRkS2Vi4hx68oTJJE',
#   'artist_name': 'John K',
#   'external_url': 'https://api.spotify.com/v1/artists/73eAAfRkS2Vi4hx68oTJJE'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                        name release_date  \
# 0  18VcdfV5jJVjn10mh0vOYt                       Vibez   2021-01-08
# 1  6rIbiUMmZJfqJRnXhVxFvg        Dream Your Life Away   2014-09-08
# 2  0KTj6k94XZh0c6IEMfxeWV  Dreamland (+ Bonus Levels)   2020-08-06
# 3  0VKcOEVdDLf95KdHfBw9AR   Night & Day (Day Edition)   2018-07-13
# 4  6CQwJn7tvfUKi4U85zuEu8                   Like 1999   2021-02-09
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/18VcdfV5jJVjn10...
# 1            13  https://open.spotify.com/album/6rIbiUMmZJfqJRn...
# 2            18  https://open.spotify.com/album/0KTj6k94XZh0c6I...
# 3            18  https://open.spotify.com/album/0VKcOEVdDLf95Kd...
# 4             1  https://open.spotify.com/album/6CQwJn7tvfUKi4U...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id      song_name  duration_ms  \
# 0  709F3MwiVvLD0LQXeKs5Cz          Vibez       163127
# 1  7yq4Qj7cqayVTp3FF9CWbm        Riptide       204280
# 2  02MWAaffLxlfxAUY7c5dvx     Heat Waves       238805
# 3  68q0rYDrGaUcaAMT2dn4Mc  Hair Too Long       206053
# 4  3aHYf6AXlWujDG9CzzT95i      Like 1999       144742
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/709F3MwiVvLD0LQ...          46
# 1  https://open.spotify.com/track/7yq4Qj7cqayVTp3...          76
# 2  https://open.spotify.com/track/02MWAaffLxlfxAU...          29
# 3  https://open.spotify.com/track/68q0rYDrGaUcaAM...          34
# 4  https://open.spotify.com/track/3aHYf6AXlWujDG9...          18
#
#              song_added                album_id               artist_id
# 0  2021-08-18T10:11:38Z  18VcdfV5jJVjn10mh0vOYt  5ZsFI1h6hIdQRw2ti0hz81
# 1  2021-11-26T17:30:45Z  6rIbiUMmZJfqJRnXhVxFvg  10exVja0key0uqUkk6LJRT
# 2  2021-12-06T19:01:19Z  0KTj6k94XZh0c6IEMfxeWV  4yvcSjfu4PC0CYQyLy4wSq
# 3  2021-08-18T10:09:24Z  0VKcOEVdDLf95KdHfBw9AR  7gAppWoH7pcYmphCVTXkzs
# 4  2021-08-18T10:07:22Z  6CQwJn7tvfUKi4U85zuEu8  7blXVKBSxdFZsIqlhdViKc

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  5ZsFI1h6hIdQRw2ti0hz81           ZAYN
# 1  10exVja0key0uqUkk6LJRT      Vance Joy
# 2  4yvcSjfu4PC0CYQyLy4wSq  Glass Animals
# 3  7gAppWoH7pcYmphCVTXkzs      The Vamps
# 4  7blXVKBSxdFZsIqlhdViKc         Valley
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5ZsFI1h6hId...
# 1  https://api.spotify.com/v1/artists/10exVja0key...
# 2  https://api.spotify.com/v1/artists/4yvcSjfu4PC...
# 3  https://api.spotify.com/v1/artists/7gAppWoH7pc...
# 4  https://api.spotify.com/v1/artists/7blXVKBSxdF...

# %%
album_df['release_date']
# Out:
# 0     2021-01-08
# 1     2014-09-08
# 2     2020-08-06
# 3     2018-07-13
# 4     2021-02-09
#          ...
# 95    2017-06-09
# 96    2020-03-25
# 97    2019-04-19
# 98    2017-09-06
# 99    2020-11-12
# Name: release_date, Length: 89, dtype: object

# %%
album_df['release_date'] = album_df['release_date'].apply(lambda x: pd.to_datetime(f"{x}-01-01") if pd.notnull(x) and len(str(x)) == 4 else x)

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      datetime64[ns, UTC]
#  6   album_id     5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 448.0+ bytes
